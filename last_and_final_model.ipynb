# %% [markdown]
# <a href="https://colab.research.google.com/github/Sidhtang/CNN-classification-using-mnist-dataset/blob/main/last_and_final_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics scikit-learn deep_sort_realtime opencv-python-headless
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.57-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.6.0)
# Collecting deep_sort_realtime
#   Downloading deep_sort_realtime-1.3.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.8.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (11.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.20.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.13-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.12.14)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.57-py3-none-any.whl (905 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 905.3/905.3 kB 27.2 MB/s eta 0:00:00
# Downloading deep_sort_realtime-1.3.2-py3-none-any.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 54.7 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.13-py3-none-any.whl (26 kB)
# Installing collected packages: deep_sort_realtime, ultralytics-thop, ultralytics
# Successfully installed deep_sort_realtime-1.3.2 ultralytics-8.3.57 ultralytics-thop-2.0.13

# %%
from ultralytics import YOLO
import cv2
import numpy as np
from collections import Counter
from sklearn.cluster import KMeans
from deep_sort_realtime.deepsort_tracker import DeepSort

# Constants
COLOR_MAP = {
    'car': (0, 255, 0),
    'truck': (255, 0, 0),
    'bus': (0, 0, 255),
    'motorcycle': (255, 255, 0),
    'bicycle': (255, 0, 255),
    'van': (0, 255, 255),
    'person': (255, 165, 0)
}

def setup_model():
    model = YOLO('yolov8x.pt')
    return model

def setup_tracker():
    return DeepSort(max_age=30, nn_budget=70, max_iou_distance=0.7)

def classify_color(rgb):
    bgr = rgb[::-1]  # Convert RGB to BGR
    hsv = cv2.cvtColor(np.uint8([[bgr]]), cv2.COLOR_BGR2HSV)[0][0]
    h, s, v = hsv

    if s < 50:  # Low saturation
        if v < 60:
            return "black"
        elif v > 200:
            return "white"
        else:
            return "gray"

    # Hue ranges for basic colors
    if 0 <= h < 10 or 160 <= h <= 180:
        return "red"
    elif 10 <= h < 25:
        return "orange"
    elif 25 <= h < 35:
        return "yellow"
    elif 35 <= h < 85:
        return "green"
    elif 85 <= h < 130:
        return "blue"
    elif 130 <= h < 160:
        return "purple"
    return "unknown"

def get_dominant_color(img, box):
    x1, y1, x2, y2 = map(int, box)
    region = img[y1:y2, x1:x2]
    pixels = region.reshape(-1, 3)
    if len(pixels) < 3:
        return "unknown"
    kmeans = KMeans(n_clusters=3, n_init=10)
    kmeans.fit(pixels)
    colors = kmeans.cluster_centers_
    labels = kmeans.labels_
    counts = Counter(labels)
    dominant_color = colors[counts.most_common(1)[0][0]]
    return classify_color(dominant_color)

def process_video(video_path, output_path, model, tracker):
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise ValueError(f"Could not open video: {video_path}")

    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))

    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        detection_list = []
        results = model(frame)  # Get detections
        for box, conf, cls in zip(results[0].boxes.xyxy, results[0].boxes.conf, results[0].boxes.cls):
            x1, y1, x2, y2 = map(int, box.tolist())
            detection = ([x1, y1, x2 - x1, y2 - y1], conf.item(), int(cls.item()))
            detection_list.append(detection)

        tracks = tracker.update_tracks(detection_list, frame=frame)

        for track in tracks:
            if not track.is_confirmed():
                continue

            try:
                track_id = track.track_id
                ltwh = track.to_ltwh()
                x1, y1 = int(ltwh[0]), int(ltwh[1])
                x2, y2 = int(ltwh[0] + ltwh[2]), int(ltwh[1] + ltwh[3])

                cls_id = track.get_det_class()
                if cls_id is None:
                    continue

                class_name = model.names[cls_id]
                conf = track.get_det_conf() or 0.0

                color = get_dominant_color(frame, [x1, y1, x2, y2]) if class_name != 'person' else 'N/A'
                label = f'{class_name} #{track_id} ({color}): {conf:.2f}'

                bbox_color = COLOR_MAP.get(class_name.lower(), (200, 200, 200))
                cv2.rectangle(frame, (x1, y1), (x2, y2), bbox_color, 3)
                cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, bbox_color, 2)
            except Exception as e:
                print(f"Error processing track {track.track_id}: {e}")

        out.write(frame)

    cap.release()
    out.release()
    print(f"Processed video saved to {output_path}")

def main():
    video_path = "/content/WhatsApp Video 2025-01-03 at 01.11.52_2850e0bf (1).mp4"
    output_path = "output_video.mp4"

    model = setup_model()
    tracker = setup_tracker()
    process_video(video_path, output_path, model, tracker)

if __name__ == "__main__":
    main()
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8x.pt to 'yolov8x.pt'...
# 100%|██████████| 131M/131M [00:00<00:00, 387MB/s]
# 0: 384x640 3 persons, 11 cars, 1 motorcycle, 67.6ms
# Speed: 7.4ms preprocess, 67.6ms inference, 972.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 11 cars, 1 motorcycle, 1 bus, 53.7ms
# Speed: 3.2ms preprocess, 53.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 11 cars, 1 motorcycle, 3 buss, 1 truck, 53.8ms
# Speed: 4.2ms preprocess, 53.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 cars, 1 motorcycle, 1 bus, 63.1ms
# Speed: 5.4ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 1 motorcycle, 3 buss, 1 truck, 66.3ms
# Speed: 3.1ms preprocess, 66.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 1 motorcycle, 2 buss, 1 truck, 63.1ms
# Speed: 8.5ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 11 cars, 1 motorcycle, 1 bus, 1 truck, 63.1ms
# Speed: 5.5ms preprocess, 63.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 10 cars, 1 motorcycle, 1 bus, 1 truck, 63.1ms
# Speed: 3.1ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 10 cars, 1 motorcycle, 1 bus, 1 truck, 63.1ms
# Speed: 3.5ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 11 cars, 1 motorcycle, 1 bus, 1 truck, 63.1ms
# Speed: 3.8ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 motorcycle, 1 bus, 1 truck, 61.7ms
# Speed: 3.0ms preprocess, 61.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 1 motorcycle, 1 bus, 1 truck, 67.5ms
# Speed: 7.0ms preprocess, 67.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 8 cars, 1 motorcycle, 1 bus, 1 truck, 63.1ms
# Speed: 3.0ms preprocess, 63.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 cars, 1 motorcycle, 2 buss, 1 truck, 68.3ms
# Speed: 3.2ms preprocess, 68.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 10 cars, 1 motorcycle, 2 buss, 1 truck, 63.1ms
# Speed: 3.0ms preprocess, 63.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 11 cars, 1 motorcycle, 2 buss, 1 truck, 63.1ms
# Speed: 3.1ms preprocess, 63.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 11 cars, 1 motorcycle, 1 bus, 1 truck, 61.7ms
# Speed: 5.2ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 11 cars, 1 motorcycle, 2 buss, 1 truck, 63.1ms
# Speed: 5.2ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 12 cars, 1 motorcycle, 1 bus, 61.8ms
# Speed: 2.9ms preprocess, 61.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 11 cars, 1 motorcycle, 1 bus, 63.1ms
# Speed: 3.0ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 14 cars, 1 motorcycle, 1 bus, 63.1ms
# Speed: 3.0ms preprocess, 63.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 12 cars, 1 motorcycle, 1 bus, 1 truck, 63.1ms
# Speed: 4.8ms preprocess, 63.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 13 cars, 1 motorcycle, 2 buss, 1 truck, 63.1ms
# Speed: 5.3ms preprocess, 63.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 10 cars, 1 motorcycle, 2 buss, 63.1ms
# Speed: 4.1ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 10 cars, 1 motorcycle, 3 buss, 63.1ms
# Speed: 9.3ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 10 cars, 1 motorcycle, 2 buss, 63.1ms
# Speed: 6.3ms preprocess, 63.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 11 cars, 1 motorcycle, 1 bus, 1 truck, 63.1ms
# Speed: 3.0ms preprocess, 63.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 11 cars, 1 motorcycle, 1 bus, 1 truck, 63.1ms
# Speed: 3.4ms preprocess, 63.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 10 cars, 1 motorcycle, 1 bus, 1 truck, 63.1ms
# Speed: 3.0ms preprocess, 63.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 10 cars, 1 motorcycle, 1 bus, 1 truck, 63.1ms
# Speed: 3.0ms preprocess, 63.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 12 cars, 1 motorcycle, 1 bus, 1 truck, 63.1ms
# Speed: 3.1ms preprocess, 63.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 3 buss, 63.1ms
# Speed: 6.9ms preprocess, 63.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 2 buss, 1 truck, 63.1ms
# Speed: 3.1ms preprocess, 63.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 13 cars, 1 bus, 1 truck, 63.1ms
# Speed: 3.2ms preprocess, 63.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 bus, 2 trucks, 71.1ms
# Speed: 2.8ms preprocess, 71.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 12 cars, 2 buss, 1 truck, 63.2ms
# Speed: 4.2ms preprocess, 63.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 12 cars, 2 buss, 63.1ms
# Speed: 3.0ms preprocess, 63.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 12 cars, 2 buss, 63.1ms
# Speed: 6.2ms preprocess, 63.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 12 cars, 2 buss, 1 truck, 63.0ms
# Speed: 2.5ms preprocess, 63.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 2 buss, 63.1ms
# Speed: 3.1ms preprocess, 63.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 11 cars, 2 buss, 63.3ms
# Speed: 7.3ms preprocess, 63.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 cars, 2 buss, 1 truck, 63.1ms
# Speed: 3.7ms preprocess, 63.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 2 buss, 1 truck, 63.1ms
# Speed: 3.1ms preprocess, 63.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 2 buss, 63.1ms
# Speed: 6.0ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 2 buss, 63.1ms
# Speed: 3.1ms preprocess, 63.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 2 buss, 63.1ms
# Speed: 4.3ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 2 buss, 63.1ms
# Speed: 3.2ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 2 buss, 65.4ms
# Speed: 3.0ms preprocess, 65.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 2 buss, 63.1ms
# Speed: 2.9ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 bus, 63.1ms
# Speed: 4.4ms preprocess, 63.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 bus, 63.2ms
# Speed: 2.9ms preprocess, 63.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 bus, 63.1ms
# Speed: 3.0ms preprocess, 63.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 bus, 61.7ms
# Speed: 2.9ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 bus, 61.8ms
# Speed: 3.9ms preprocess, 61.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 bus, 61.7ms
# Speed: 5.7ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 bus, 62.6ms
# Speed: 3.1ms preprocess, 62.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 bus, 61.7ms
# Speed: 6.7ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 bus, 61.7ms
# Speed: 2.8ms preprocess, 61.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 bus, 61.7ms
# Speed: 10.5ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 bus, 61.8ms
# Speed: 3.1ms preprocess, 61.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 13 cars, 1 bus, 61.7ms
# Speed: 3.7ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 12 cars, 1 bus, 62.0ms
# Speed: 6.7ms preprocess, 62.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 13 cars, 1 bus, 61.8ms
# Speed: 3.3ms preprocess, 61.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 13 cars, 1 bus, 61.7ms
# Speed: 3.2ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 12 cars, 1 bus, 61.7ms
# Speed: 3.4ms preprocess, 61.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 bus, 61.9ms
# Speed: 3.0ms preprocess, 61.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 bus, 61.8ms
# Speed: 2.9ms preprocess, 61.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 bus, 61.7ms
# Speed: 2.9ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 13 cars, 1 bus, 61.7ms
# Speed: 3.4ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 13 cars, 1 bus, 61.7ms
# Speed: 3.5ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 12 cars, 61.7ms
# Speed: 8.1ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 13 cars, 61.7ms
# Speed: 4.5ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 61.7ms
# Speed: 3.1ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 61.7ms
# Speed: 5.9ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 61.7ms
# Speed: 7.5ms preprocess, 61.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 12 cars, 61.8ms
# Speed: 2.9ms preprocess, 61.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 12 cars, 1 bus, 64.2ms
# Speed: 3.0ms preprocess, 64.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 14 cars, 1 bus, 61.8ms
# Speed: 3.1ms preprocess, 61.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 14 cars, 1 bus, 61.7ms
# Speed: 3.2ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 13 cars, 1 bus, 61.8ms
# Speed: 4.3ms preprocess, 61.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 1 bus, 61.7ms
# Speed: 3.0ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 14 cars, 1 bus, 61.7ms
# Speed: 6.8ms preprocess, 61.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:1389: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# 0: 384x640 2 persons, 12 cars, 1 bus, 61.8ms
# Speed: 4.7ms preprocess, 61.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 12 cars, 1 bus, 61.8ms
# Speed: 5.9ms preprocess, 61.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 13 cars, 1 bus, 61.7ms
# Speed: 5.2ms preprocess, 61.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 14 cars, 1 bus, 62.8ms
# Speed: 4.1ms preprocess, 62.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 12 cars, 1 bus, 61.7ms
# Speed: 3.7ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 12 cars, 1 bus, 61.7ms
# Speed: 7.3ms preprocess, 61.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 13 cars, 1 bus, 61.7ms
# Speed: 3.7ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 12 cars, 1 bus, 61.7ms
# Speed: 5.9ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 13 cars, 1 bus, 61.7ms
# Speed: 3.9ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 bus, 61.7ms
# Speed: 5.6ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 12 cars, 1 bus, 61.8ms
# Speed: 3.1ms preprocess, 61.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 bus, 61.7ms
# Speed: 3.8ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 12 cars, 1 bus, 61.7ms
# Speed: 3.4ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 12 cars, 1 bus, 62.2ms
# Speed: 5.7ms preprocess, 62.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 11 cars, 1 bus, 62.0ms
# Speed: 3.3ms preprocess, 62.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 bus, 61.7ms
# Speed: 7.8ms preprocess, 61.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons,
ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 61.7ms
# Speed: 2.8ms preprocess, 61.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 61.6ms
# Speed: 4.1ms preprocess, 61.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 61.7ms
# Speed: 3.1ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 61.6ms
# Speed: 4.2ms preprocess, 61.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 62.2ms
# Speed: 3.1ms preprocess, 62.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 62.0ms
# Speed: 3.0ms preprocess, 62.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 61.7ms
# Speed: 3.0ms preprocess, 61.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 61.7ms
# Speed: 3.3ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 61.7ms
# Speed: 3.4ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 61.7ms
# Speed: 4.2ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 61.7ms
# Speed: 4.7ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 61.7ms
# Speed: 2.5ms preprocess, 61.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 61.7ms
# Speed: 3.3ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 61.7ms
# Speed: 2.9ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 61.7ms
# Speed: 3.1ms preprocess, 61.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 61.7ms
# Speed: 3.2ms preprocess, 61.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 61.7ms
# Speed: 2.9ms preprocess, 61.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 61.7ms
# Speed: 3.0ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 61.7ms
# Speed: 5.0ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 61.7ms
# Speed: 2.8ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 61.7ms
# Speed: 4.8ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 61.7ms
# Speed: 6.8ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 61.7ms
# Speed: 3.9ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processed video saved to output_video.mp4

# %%
from ultralytics import YOLO
import cv2
import numpy as np
from collections import Counter
from sklearn.cluster import KMeans
from deep_sort_realtime.deepsort_tracker import DeepSort

# Constants
COLOR_MAP = {
    'car': (0, 255, 0),
    'truck': (255, 0, 0),
    'bus': (0, 0, 255),
    'motorcycle': (255, 255, 0),
    'bicycle': (255, 0, 255),
    'van': (0, 255, 255),
    'person': (255, 165, 0)
}

def setup_model():
    model = YOLO('yolov8x.pt')
    return model

def setup_tracker():
    return DeepSort(max_age=30, nn_budget=70, max_iou_distance=0.7)

def classify_color(rgb):
    bgr = rgb[::-1]  # Convert RGB to BGR
    hsv = cv2.cvtColor(np.uint8([[bgr]]), cv2.COLOR_BGR2HSV)[0][0]
    h, s, v = hsv

    if s < 50:  # Low saturation
        if v < 60:
            return "black"
        elif v > 200:
            return "white"
        else:
            return "gray"

    # Hue ranges for basic colors
    if 0 <= h < 10 or 160 <= h <= 180:
        return "red"
    elif 10 <= h < 25:
        return "orange"
    elif 25 <= h < 35:
        return "yellow"
    elif 35 <= h < 85:
        return "green"
    elif 85 <= h < 130:
        return "blue"
    elif 130 <= h < 160:
        return "purple"
    return "unknown"

def get_dominant_color(img, box):
    x1, y1, x2, y2 = map(int, box)
    region = img[y1:y2, x1:x2]
    pixels = region.reshape(-1, 3)
    if len(pixels) < 3:
        return "unknown"
    kmeans = KMeans(n_clusters=3, n_init=10)
    kmeans.fit(pixels)
    colors = kmeans.cluster_centers_
    labels = kmeans.labels_
    counts = Counter(labels)
    dominant_color = colors[counts.most_common(1)[0][0]]
    return classify_color(dominant_color)

def process_video(video_path, output_path, model, tracker):
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise ValueError(f"Could not open video: {video_path}")

    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))

    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        detection_list = []
        results = model(frame)  # Get detections
        for box, conf, cls in zip(results[0].boxes.xyxy, results[0].boxes.conf, results[0].boxes.cls):
            x1, y1, x2, y2 = map(int, box.tolist())
            detection = ([x1, y1, x2 - x1, y2 - y1], conf.item(), int(cls.item()))
            detection_list.append(detection)

        tracks = tracker.update_tracks(detection_list, frame=frame)

        for track in tracks:
            if not track.is_confirmed():
                continue

            try:
                track_id = track.track_id
                ltwh = track.to_ltwh()
                x1, y1 = int(ltwh[0]), int(ltwh[1])
                x2, y2 = int(ltwh[0] + ltwh[2]), int(ltwh[1] + ltwh[3])

                cls_id = track.get_det_class()
                if cls_id is None:
                    continue

                class_name = model.names[cls_id]
                conf = track.get_det_conf() or 0.0

                color = get_dominant_color(frame, [x1, y1, x2, y2]) if class_name != 'person' else 'N/A'
                label = f'{class_name} #{track_id} ({color}): {conf:.2f}'

                bbox_color = COLOR_MAP.get(class_name.lower(), (200, 200, 200))
                cv2.rectangle(frame, (x1, y1), (x2, y2), bbox_color, 3)
                cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, bbox_color, 2)
            except Exception as e:
                print(f"Error processing track {track.track_id}: {e}")

        out.write(frame)

    cap.release()
    out.release()
    print(f"Processed video saved to {output_path}")

def main():
    video_path = "/content/1734540857073 (1).mp4"
    output_path = "result_video.mp4"

    model = setup_model()
    tracker = setup_tracker()
    process_video(video_path, output_path, model, tracker)

if __name__ == "__main__":
    main()
# Out:
# 0: 384x640 4 persons, 8 cars, 1 traffic light, 62.6ms
# Speed: 3.2ms preprocess, 62.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 cars, 1 traffic light, 43.0ms
# Speed: 3.0ms preprocess, 43.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 cars, 1 traffic light, 43.3ms
# Speed: 3.0ms preprocess, 43.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 7 cars, 1 traffic light, 61.8ms
# Speed: 7.0ms preprocess, 61.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 7 cars, 1 traffic light, 61.8ms
# Speed: 6.3ms preprocess, 61.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 cars, 1 traffic light, 61.8ms
# Speed: 7.2ms preprocess, 61.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 1 traffic light, 61.7ms
# Speed: 3.5ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 1 traffic light, 62.9ms
# Speed: 4.9ms preprocess, 62.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 1 traffic light, 61.7ms
# Speed: 5.6ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 traffic light, 61.8ms
# Speed: 6.4ms preprocess, 61.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 cars, 1 traffic light, 61.7ms
# Speed: 3.0ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 cars, 1 traffic light, 61.7ms
# Speed: 3.1ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 cars, 1 traffic light, 61.7ms
# Speed: 3.1ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 5 cars, 1 traffic light, 61.7ms
# Speed: 5.8ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 9 cars, 1 traffic light, 61.7ms
# Speed: 4.4ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bicycle, 5 cars, 1 traffic light, 61.7ms
# Speed: 4.3ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 traffic light, 62.5ms
# Speed: 4.5ms preprocess, 62.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 1 traffic light, 61.7ms
# Speed: 3.1ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 1 traffic light, 61.7ms
# Speed: 7.0ms preprocess, 61.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 1 traffic light, 1 handbag, 61.7ms
# Speed: 3.1ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 1 traffic light, 1 handbag, 61.9ms
# Speed: 3.5ms preprocess, 61.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 traffic light, 1 handbag, 61.7ms
# Speed: 3.1ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 traffic light, 61.7ms
# Speed: 6.3ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 traffic light, 61.7ms
# Speed: 3.0ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 traffic light, 61.7ms
# Speed: 3.1ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 traffic light, 64.8ms
# Speed: 3.8ms preprocess, 64.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 traffic light, 61.7ms
# Speed: 4.0ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 traffic light, 61.8ms
# Speed: 3.9ms preprocess, 61.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 traffic light, 61.7ms
# Speed: 2.9ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 traffic light, 61.8ms
# Speed: 3.1ms preprocess, 61.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 traffic light, 64.1ms
# Speed: 3.0ms preprocess, 64.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 traffic light, 61.7ms
# Speed: 6.7ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 1 traffic light, 61.8ms
# Speed: 5.3ms preprocess, 61.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 1 traffic light, 61.7ms
# Speed: 3.8ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 traffic light, 61.7ms
# Speed: 6.4ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 traffic light, 61.8ms
# Speed: 3.4ms preprocess, 61.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 traffic light, 62.0ms
# Speed: 3.9ms preprocess, 62.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 traffic light, 61.7ms
# Speed: 5.2ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 6 cars, 1 traffic light, 61.7ms
# Speed: 3.2ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 6 cars, 1 traffic light, 61.7ms
# Speed: 2.4ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 6 cars, 1 traffic light, 61.7ms
# Speed: 5.8ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 cars, 1 traffic light, 61.7ms
# Speed: 3.2ms preprocess, 61.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 cars, 1 traffic light, 64.3ms
# Speed: 3.6ms preprocess, 64.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 1 traffic light, 61.8ms
# Speed: 3.3ms preprocess, 61.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 1 traffic light, 61.7ms
# Speed: 5.6ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 cars, 1 traffic light, 61.7ms
# Speed: 6.2ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 cars, 1 traffic light, 61.7ms
# Speed: 7.7ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 cars, 1 traffic light, 61.8ms
# Speed: 4.3ms preprocess, 61.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 1 traffic light, 61.7ms
# Speed: 2.9ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 1 traffic light, 61.7ms
# Speed: 3.1ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 traffic light, 61.7ms
# Speed: 3.0ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 traffic light, 61.7ms
# Speed: 3.0ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 traffic light, 61.8ms
# Speed: 6.9ms preprocess, 61.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 traffic light, 61.7ms
# Speed: 3.1ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 traffic light, 61.7ms
# Speed: 6.4ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 1 traffic light, 61.7ms
# Speed: 6.6ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 traffic light, 61.7ms
# Speed: 6.8ms preprocess, 61.7ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 1 traffic light, 61.7ms
# Speed: 3.1ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 traffic light, 61.7ms
# Speed: 3.9ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 1 traffic light, 61.7ms
# Speed: 9.8ms preprocess, 61.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 traffic light, 61.7ms
# Speed: 7.4ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 traffic light, 61.7ms
# Speed: 8.5ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 traffic light, 61.7ms
# Speed: 3.1ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 traffic light, 61.7ms
# Speed: 3.1ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 traffic light, 61.7ms
# Speed: 6.3ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 traffic light, 61.7ms
# Speed: 3.3ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 traffic light, 61.7ms
# Speed: 3.7ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 traffic light, 61.7ms
# Speed: 6.1ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 traffic light, 61.7ms
# Speed: 3.1ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 traffic light, 61.7ms
# Speed: 3.0ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 traffic light, 63.8ms
# Speed: 7.7ms preprocess, 63.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 traffic light, 61.7ms
# Speed: 6.0ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 traffic light, 63.8ms
# Speed: 3.3ms preprocess, 63.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 traffic light, 61.7ms
# Speed: 6.5ms preprocess, 61.7ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 traffic light, 61.7ms
# Speed: 6.8ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 traffic light, 61.8ms
# Speed: 3.2ms preprocess, 61.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 traffic light, 61.7ms
# Speed: 4.1ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 traffic light, 62.3ms
# Speed: 5.9ms preprocess, 62.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 traffic light, 61.7ms
# Speed: 3.1ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 traffic light, 61.7ms
# Speed: 3.1ms preprocess, 61.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 traffic light, 61.7ms
# Speed: 6.3ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 traffic light, 61.7ms
# Speed: 3.2ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 traffic light, 61.8ms
# Speed: 3.0ms preprocess, 61.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 traffic light, 61.7ms
# Speed: 5.8ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 traffic light, 61.7ms
# Speed: 4.2ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 traffic light, 61.8ms
# Speed: 2.9ms preprocess, 61.8ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 traffic light, 61.7ms
# Speed: 9.2ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 traffic light, 61.7ms
# Speed: 4.7ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 traffic light, 61.7ms
# Speed: 7.2ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 traffic light, 61.7ms
# Speed: 3.2ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 traffic light, 63.1ms
# Speed: 3.1ms preprocess, 63.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 traffic light, 61.7ms
# Speed: 3.1ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 motorcycle, 1 traffic light, 64.6ms
# Speed: 3.3ms preprocess, 64.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 1 motorcycle, 1 traffic light, 61.7ms
# Speed: 3.2ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 1 traffic light, 61.8ms
# Speed: 4.5ms preprocess, 61.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 1 motorcycle, 1 traffic light, 61.7ms
# Speed: 3.9ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 motorcycle, 1 traffic light, 61.7ms
# Speed: 4.4ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 motorcycle, 1 traffic light, 61.7ms
# Speed: 3.2ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 motorcycle, 1 airplane, 1 traffic light, 61.7ms
# Speed: 4.5ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 1 airplane, 1 traffic light, 61.7ms
# Speed: 3.1ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 motorcycle, 1 airplane, 1 traffic light, 61.7ms
# Speed: 3.1ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 motorcycle, 1 airplane, 1 traffic light, 61.7ms
# Speed: 6.7ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 motorcycle, 1 airplane, 1 traffic light, 62.3ms
# Speed: 3.5ms preprocess, 62.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 motorcycle, 1 airplane, 1 traffic light, 61.8ms
# Speed: 3.2ms preprocess, 61.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 airplane, 1 traffic light, 61.7ms
# Speed: 3.9ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 airplane, 1 traffic light, 63.1ms
# Speed: 3.2ms preprocess, 63.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 airplane, 1 traffic light, 62.1ms
# Speed: 5.0ms preprocess, 62.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 traffic light, 62.7ms
# Speed: 4.6ms preprocess, 62.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 traffic light, 61.7ms
# Speed: 3.1ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 traffic light, 61.7ms
# Speed: 5.7ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 traffic light, 61.7ms
# Speed: 4.8ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 traffic light, 61.7ms
# Speed: 7.0ms preprocess, 61.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 traffic light, 61.7ms
# Speed: 3.1ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 traffic light, 61.7ms
# Speed: 4.3ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 traffic light, 61.8ms
# Speed: 4.1ms preprocess, 61.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars,
ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 traffic light, 1 parking meter, 61.7ms
# Speed: 3.2ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 traffic lights, 61.7ms
# Speed: 9.5ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 airplane, 1 traffic light, 62.7ms
# Speed: 4.5ms preprocess, 62.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 airplane, 1 traffic light, 67.0ms
# Speed: 3.1ms preprocess, 67.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 traffic light, 61.8ms
# Speed: 6.7ms preprocess, 61.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 traffic light, 61.7ms
# Speed: 2.9ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 airplane, 61.7ms
# Speed: 4.7ms preprocess, 61.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 airplane, 2 traffic lights, 61.7ms
# Speed: 4.7ms preprocess, 61.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 2 traffic lights, 61.7ms
# Speed: 7.0ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 2 traffic lights, 61.7ms
# Speed: 3.1ms preprocess, 61.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 3 traffic lights, 61.7ms
# Speed: 3.1ms preprocess, 61.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 2 traffic lights, 61.7ms
# Speed: 6.8ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 2 traffic lights, 61.7ms
# Speed: 4.0ms preprocess, 61.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 2 traffic lights, 62.4ms
# Speed: 4.7ms preprocess, 62.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 2 traffic lights, 1 parking meter, 61.7ms
# Speed: 3.2ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 traffic light, 61.7ms
# Speed: 3.5ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 traffic light, 61.7ms
# Speed: 3.3ms preprocess, 61.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 2 traffic lights, 61.7ms
# Speed: 2.9ms preprocess, 61.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 61.7ms
# Speed: 3.3ms preprocess, 61.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 traffic light, 61.7ms
# Speed: 2.9ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 2 traffic lights, 61.7ms
# Speed: 3.1ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 2 traffic lights, 61.8ms
# Speed: 3.2ms preprocess, 61.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 traffic light, 61.9ms
# Speed: 4.4ms preprocess, 61.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 traffic light, 61.7ms
# Speed: 3.1ms preprocess, 61.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 traffic light, 61.8ms
# Speed: 4.8ms preprocess, 61.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 2 traffic lights, 61.7ms
# Speed: 3.0ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 traffic light, 61.7ms
# Speed: 4.7ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 traffic light, 61.7ms
# Speed: 3.2ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 traffic light, 61.9ms
# Speed: 4.4ms preprocess, 61.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 traffic light, 61.8ms
# Speed: 3.9ms preprocess, 61.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 traffic light, 61.7ms
# Speed: 3.1ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 traffic light, 61.7ms
# Speed: 8.9ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 traffic lights, 61.7ms
# Speed: 3.2ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 traffic lights, 61.7ms
# Speed: 3.3ms preprocess, 61.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 traffic light, 61.7ms
# Speed: 3.7ms preprocess, 61.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 traffic light, 62.2ms
# Speed: 3.2ms preprocess, 62.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 2 traffic lights, 61.7ms
# Speed: 3.2ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 traffic lights, 61.7ms
# Speed: 4.6ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars,
ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 traffic light, 61.8ms
# Speed: 3.1ms preprocess, 61.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 1 traffic light, 61.7ms
# Speed: 3.8ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 1 traffic light, 61.7ms
# Speed: 3.5ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 traffic light, 61.7ms
# Speed: 3.2ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 traffic light, 61.7ms
# Speed: 3.6ms preprocess, 61.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 traffic light, 61.7ms
# Speed: 6.7ms preprocess, 61.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 traffic light, 1 cell phone, 61.7ms
# Speed: 5.2ms preprocess, 61.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 traffic light, 61.7ms
# Speed: 3.2ms preprocess, 61.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 1 traffic light, 61.7ms
# Speed: 10.0ms preprocess, 61.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 1 traffic light, 61.8ms
# Speed: 7.6ms preprocess, 61.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 1 truck, 1 traffic light, 61.7ms
# Speed: 3.5ms preprocess, 61.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 truck, 1 traffic light, 61.7ms
# Speed: 7.0ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 traffic light, 61.7ms
# Speed: 5.2ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 traffic light, 61.7ms
# Speed: 2.3ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 traffic light, 1 handbag, 61.7ms
# Speed: 3.5ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 traffic light, 61.8ms
# Speed: 3.5ms preprocess, 61.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 traffic light, 61.7ms
# Speed: 4.1ms preprocess, 61.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 traffic light, 61.7ms
# Speed: 2.9ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 traffic light, 62.2ms
# Speed: 4.6ms preprocess, 62.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 1 traffic light, 1 bird, 61.7ms
# Speed: 4.1ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 1 traffic light, 69.7ms
# Speed: 3.5ms preprocess, 69.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 traffic light, 61.7ms
# Speed: 8.2ms preprocess, 61.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 1 traffic light, 61.7ms
# Speed: 7.5ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 traffic light, 1 bird, 61.7ms
# Speed: 5.7ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 1 traffic light, 61.7ms
# Speed: 4.5ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 traffic light, 61.8ms
# Speed: 3.2ms preprocess, 61.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 1 traffic light, 61.7ms
# Speed: 6.6ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 1 traffic light, 61.8ms
# Speed: 3.0ms preprocess, 61.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 traffic light, 61.7ms
# Speed: 8.2ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 traffic light, 61.8ms
# Speed: 3.4ms preprocess, 61.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 traffic light, 61.8ms
# Speed: 3.3ms preprocess, 61.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 traffic light, 61.7ms
# Speed: 7.9ms preprocess, 61.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 traffic light, 61.7ms
# Speed: 3.1ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 traffic light, 61.7ms
# Speed: 4.1ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 traffic light, 67.2ms
# Speed: 3.0ms preprocess, 67.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 traffic light, 61.7ms
# Speed: 6.7ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 traffic light, 61.8ms
# Speed: 3.2ms preprocess, 61.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 traffic light, 61.7ms
# Speed: 3.1ms preprocess, 61.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars,